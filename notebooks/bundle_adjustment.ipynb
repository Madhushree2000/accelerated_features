# %%
from pyba.CameraNetwork import CameraNetwork
import pickle
import glob
import numpy as np

image_path = '/Volumes/Lenovo PS6/Dataset/cam_{cam_id}/img_00000{img_id}.jpg'
pr_path = '/Volumes/Lenovo PS6/Dataset/short_for_bundle_adjustment1.pkl'

d = pickle.load(open(glob.glob(pr_path)[0], 'rb'))

# %%
d.keys()
# Out:
# dict_keys([0, 'points_2d'])

# %%
d[0]['tvec'].ndim
# Out:
# 1

# %%
p_2d = d['points_2d']*[720, 540]

# %%
camNet = CameraNetwork(points2d=d['points_2d'], calib=d, image_path=image_path)

# %%
import matplotlib.pyplot as plt
img = camNet.plot_2d(1, points='points2d')
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 959.5, 479.5, -0.5)

# %%
from pyba.pyba import bundle_adjust 
bundle_adjust(camNet)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 2
#       1 from pyba.pyba import bundle_adjust
# ----> 2 bundle_adjust(camNet)
#
# File ~/opt/anaconda3/envs/xfeat/lib/python3.8/site-packages/pyba/pyba.py:31, in bundle_adjust(camNet, max_num_images, update_intrinsic, update_distort)
#      21 (
#      22     x0,
#      23     points_2d,
#    (...)
#      27     point_indices,
#      28 ) = prepare_bundle_adjust_param(camNet=camNet, max_num_images=max_num_images)
#      30 A = bundle_adjustment_sparsity(n_cameras, n_points, camera_indices, point_indices)
# ---> 31 res = least_squares(
#      32     residuals,
#      33     x0,
#      34     jac_sparsity=A,
#      35     verbose=2,
#      36     x_scale="jac",
#      37     ftol=1e-4,
#      38     method="trf",
#      39     args=(
#      40         camNet.cam_list,
#      41         n_cameras,
# ...

# %%
fig = plt.figure(figsize=(10,10))
ax3d = fig.add_subplot(111, projection='3d')

camNet.draw(ax3d, size=20)
camNet.plot_3d(ax3d, img_id=0, size=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 5
#       2 ax3d = fig.add_subplot(111, projection='3d')
#       4 camNet.draw(ax3d, size=20)
# ----> 5 camNet.plot_3d(ax3d, img_id=0, size=10)
#
# File ~/opt/anaconda3/envs/xfeat/lib/python3.8/site-packages/pyba/CameraNetwork.py:163, in CameraNetwork.plot_3d(self, ax_3d, img_id, size, thickness)
#     152 def plot_3d(
#     153     self,
#     154     ax_3d,
#    (...)
#     157     thickness: float = 5.0,
#     158 ):
#     159     plot_3d(
#     160         ax_3d,
#     161         self.points3d[img_id] * size,
#     162         self.bones,
# --> 163         np.array(self.colors) / 255,
#     164         lim=3,
#     165         thickness=thickness,
#     166         zorder=None,
#     167     )
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'
# ...
