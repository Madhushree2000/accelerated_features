# %%
# !git clone --branch thesis https://github.com/Madhushree2000/accelerated_features.git
# Out:
# Cloning into 'accelerated_features'...
# remote: Enumerating objects: 354, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 354 (delta 160), reused 94 (delta 81), pack-reused 146 (from 2)
# Receiving objects: 100% (354/354), 64.19 MiB | 34.02 MiB/s, done.
# Resolving deltas: 100% (215/215), done.

# %%
# %cd accelerated_features
# !mkdir ckpt
# Out:
# /kaggle/working/accelerated_features

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 MB 27.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.1 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 32.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.5 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.1 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip3 install kornia lightning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 21.5 MB/s eta 0:00:0000:01
# ...

# %%
# %cd third_party
# !pwd
# Out:
# /kaggle/working/accelerated_features/third_party
# /kaggle/working/accelerated_features/third_party

# %%
# !rmdir ALIKE

# %%
# !git clone https://github.com/Shiaoming/ALIKE.git
# Out:
# Cloning into 'ALIKE'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 126 (delta 12), reused 12 (delta 12), pack-reused 110 (from 1)
# Receiving objects: 100% (126/126), 30.65 MiB | 30.80 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# %cd /kaggle/working/accelerated_features
# Out:
# /kaggle/working/accelerated_features

# %%
# !python3 -m modules.eval.evaluation \
--dataset-dir "/kaggle/input/mega1500/Mega1500" \
--ransac-thr 2.5 \
--checkpoint-dir "/kaggle/working/accelerated_features/figs/chkpoints" \
--output-file "/kaggle/working/accelerated_features/assets/megadepth_1500.json" \
--plots-dir "/kaggle/working/plots"
# Out:
# Error loading existing results: 'list' object has no attribute 'get'
# Found 1 checkpoint files
# loading weights from: /kaggle/working/accelerated_features/modules/../weights/xfeat.pt
# ...

# %%
# %cd ..
# !pwd

# %%
# !rm -r accelerated_features

# %%
# !git clone --branch thesis https://github.com/Madhushree2000/accelerated_features.git
# %cd accelerated_features
# !mkdir ckpt

# %%
# %cd third_party
# !pwd
# !rmdir ALIKE
# !git clone https://github.com/Shiaoming/ALIKE.git
# %cd /kaggle/working/accelerated_features
