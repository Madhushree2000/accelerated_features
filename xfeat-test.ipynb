# %%
# !git clone --branch thesis https://github.com/Madhushree2000/accelerated_features.git
# Out:
# Cloning into 'accelerated_features'...
# remote: Enumerating objects: 508, done.
# remote: Counting objects: 100% (362/362), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 508 (delta 289), reused 175 (delta 138), pack-reused 146 (from 2)
# Receiving objects: 100% (508/508), 66.32 MiB | 28.90 MiB/s, done.
# Resolving deltas: 100% (344/344), done.

# %%
# %cd accelerated_features
# !pwd
# Out:
# /kaggle/working/accelerated_features
# /kaggle/working/accelerated_features

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 MB 23.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 42.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.0 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip3 install kornia lightning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 14.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !python3 -m modules.eval.eval40 \
--dataset-dir "/kaggle/input/smaller-validation-set/Traj_04_small" \
--ransac-thr 1.5 \
--json-file "/kaggle/input/smaller-validation-set/Traj_04_small/all_pairs_merged.json" \
--checkpoint-dir "/kaggle/working/accelerated_features/chkpoints"
# Out:
# Dataset loaded with 330 image pairs across 5 folders
# Found 4 checkpoint files
# loading weights from: /kaggle/working/accelerated_features/modules/../weights/xfeat.pt
# ...

# %%
# !python3 -m modules.eval.eval40 \
--dataset-dir "/kaggle/input/smaller-validation-set/Traj_04_small" \
--ransac-thr 2.5 \
--json-file "/kaggle/input/smaller-validation-set/Traj_04_small/output_jsons/new_pairs_merged.json" \
--checkpoint-dir "/kaggle/working/accelerated_features/chkpoints"
# Out:
# Dataset loaded with 660 image pairs across 5 folders
# Found 4 checkpoint files
# loading weights from: /kaggle/working/accelerated_features/modules/../weights/xfeat.pt
# ...

# %%
# !python3 -m modules.eval.eval40 \
--dataset-dir "/kaggle/input/smaller-validation-set/Traj_04_small" \
--ransac-thr 2.5 \
--json-file "/kaggle/input/smaller-validation-set/Traj_04_small/all_pairs_merged.json" \
--checkpoint-dir "/kaggle/working/accelerated_features/chkpoints"
# Out:
# Dataset loaded with 330 image pairs across 5 folders
# Found 4 checkpoint files
# Skipping already processed checkpoint: xfeat_default_10000.pth
# Skipping already processed checkpoint: xfeat_default_30000.pth
# Skipping already processed checkpoint: xfeat_default_50000.pth
# Skipping already processed checkpoint: xfeat_default_79000.pth
# Error saving results: cannot access local variable 'model_type' where it is not associated with a value
# Error saving to fallback location: cannot access local variable 'model_type' where it is not associated with a value
# Plots saved to directory: plots
#
# Best checkpoint:
# Step: 50000
# File: xfeat_default_50000.pth
# Metrics:
# auc@5: 0.00
# auc@10: 0.23
# auc@20: 1.15
# mAcc@5: 0.00
# mAcc@10: 0.61
# mAcc@20: 3.94

# %%
# !python3 -m modules.eval.megadepth1500 \
--dataset-dir "/kaggle/input/mega1500/Mega1500" \
--ransac-thr 2.5 \
--output-file "/kaggle/working/accelerated_features/assets/megadepth_1500.json" \
--plots-dir "/kaggle/working/plots"
# Out:
# usage: megadepth1500.py [-h] --dataset-dir DATASET_DIR [--matcher {xfeat,xfeat-star,alike}]
#                         [--ransac-thr RANSAC_THR]
# megadepth1500.py: error: unrecognized arguments: --checkpoint-dir /kaggle/working/accelerated_features/figs/chkpoints --output-file /kaggle/working/accelerated_features/assets/megadepth_1500.json --plots-dir /kaggle/working/plots

# %%
# !python3 -m modules.eval.evaluation \
--dataset-dir "/kaggle/input/mega1500/Mega1500" \
--ransac-thr 2.5 \
--checkpoint-dir "/kaggle/working/accelerated_features/figs/chkpoints" \
--output-file "/kaggle/working/accelerated_features/assets/megadepth_1500.json" \
--plots-dir "/kaggle/working/plots"
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/kaggle/working/accelerated_features/modules/eval/evaluation.py", line 369, in <module>
#     main()
#   File "/kaggle/working/accelerated_features/modules/eval/evaluation.py", line 210, in main
#     raise FileNotFoundError(f"Checkpoint directory not found: {checkpoint_dir}")
# FileNotFoundError: Checkpoint directory not found: /kaggle/working/accelerated_features/figs/chkpoints

# %%
# %cd ..
# !pwd
# Out:
# /kaggle/working
# /kaggle/working

# %%
# !rm -r accelerated_features

# %%
# !git clone --branch thesis https://github.com/Madhushree2000/accelerated_features.git
# %cd accelerated_features
# !mkdir ckpt

# %%
# %cd third_party
# !pwd
# !rmdir ALIKE
# !git clone https://github.com/Shiaoming/ALIKE.git
# %cd /kaggle/working/accelerated_features
